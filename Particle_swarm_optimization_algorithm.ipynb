# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaliniAnandaPhD/ShaliniAnandaPhD/blob/main/Particle_swarm_optimization_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The Particle Swarm Optimization (PSO) algorithm is a nature-inspired optimization technique developed by Kennedy and Eberhart in 1995. The 2007 work by Poli, Kennedy, and Blackwell provides a more formalized description of the PSO algorithm.
#
# ### Kennedy and Eberhart (1995) vs Poli, Kennedy and Blackwell (2007)
#
# The core idea of both versions remains the same—particles "fly" through the solution space by updating their positions and velocities over time, influenced by their own best-known positions and the best-known positions of their neighbors or the swarm as a whole. However, there are some notable differences in the way they are presented.
#
# #### Initialization
# Both versions suggest initializing the particle swarm by setting initial positions and velocities randomly. This is a common approach, as it helps to search a wide range of the solution space initially.
#
# #### Fitness Calculation
# Both the 1995 and 2007 versions emphasize calculating a fitness value for each particle based on the objective function to be minimized or maximized. Based on this fitness value, the algorithm updates the personal best and the global best values for the swarm.
#
# #### Update Rules
# Both versions specify that particles update their velocity and position based on personal and global best positions. However, the 2007 version provides a more formalized mathematical representation for updating the velocity:
#
# \[ v = v + c1 \times \text{rand}() \times (pbest - x) + c2 \times \text{rand}() \times (gbest - x) \]
#
# Here, \( c1 \) and \( c2 \) are acceleration coefficients, \(\text{rand}()\), is a random number between 0 and 1, \( pbest \) is the personal best position, \( gbest \) is the global best position, \( x \) is the current position, and \( v \) is the velocity.
#
# #### Stopping Criteria
# Both versions suggest that the algorithm should continue iterating until either a maximum number of iterations is reached or some minimum error criteria is met.
#
# #### Summary
# Overall, while the essence of the algorithm hasn't changed, the 2007 version by Poli, Kennedy, and Blackwell provides a more rigorous and formal description of PSO. It's often beneficial to refer to both versions for a more comprehensive understanding of the algorithm.

# %%
import numpy as np

# Objective function to minimize (f(x) = x^2)
def objective_function(x):
    return x ** 2

# Initialize particle swarm
n_particles = 30
n_dimensions = 1
x_min, x_max = -10, 10
v_min, v_max = -1, 1
x = np.random.uniform(x_min, x_max, (n_particles, n_dimensions))
v = np.random.uniform(v_min, v_max, (n_particles, n_dimensions))
pbest = np.copy(x)
gbest = np.min(pbest)
gbest_position = np.copy(x[np.argmin(pbest)])

# PSO parameters
max_iterations = 100
c1 = 1.5
c2 = 1.5

# Main PSO loop
for iteration in range(max_iterations):

    # Calculate fitness value for each particle
    fitness_values = objective_function(x)

    # Update personal best and global best
    for i in range(n_particles):
        if fitness_values[i] < objective_function(pbest[i]):
            pbest[i] = x[i]

    current_gbest = np.min(pbest)
    if current_gbest < gbest:
        gbest = current_gbest
        gbest_position = x[np.argmin(pbest)]

    # Update velocity and position
    for i in range(n_particles):
        v[i] = v[i] + c1 * np.random.rand() * (pbest[i] - x[i]) + c2 * np.random.rand() * (gbest_position - x[i])
        x[i] = x[i] + v[i]

    # Print the current global best value
    print(f"Iteration {iteration+1}: Global best value is {gbest}")

print(f"The final global best position is {gbest_position} with a value of {gbest}")
# Out:
# Iteration 1: Global best value is -8.834928404850636
# Iteration 2: Global best value is -8.834928404850636
# Iteration 3: Global best value is -8.834928404850636
# Iteration 4: Global best value is -8.834928404850636
# Iteration 5: Global best value is -8.834928404850636
# Iteration 6: Global best value is -8.834928404850636
# Iteration 7: Global best value is -8.834928404850636
# Iteration 8: Global best value is -8.834928404850636
# Iteration 9: Global best value is -8.834928404850636
# Iteration 10: Global best value is -8.834928404850636
# Iteration 11: Global best value is -8.834928404850636
# Iteration 12: Global best value is -8.834928404850636
# Iteration 13: Global best value is -8.834928404850636
# Iteration 14: Global best value is -8.834928404850636
# Iteration 15: Global best value is -8.834928404850636
# Iteration 16: Global best value is -8.834928404850636
# Iteration 17: Global best value is -8.834928404850636
# Iteration 18: Global best value is -8.834928404850636
# Iteration 19: Global best value is -8.834928404850636
# Iteration 20: Global best value is -8.834928404850636
# Iteration 21: Global best value is -8.834928404850636
# Iteration 22: Global best value is -8.834928404850636
# Iteration 23: Global best value is -8.834928404850636
# Iteration 24: Global best value is -8.834928404850636
# Iteration 25: Global best value is -8.834928404850636
# Iteration 26: Global best value is -8.834928404850636
# Iteration 27: Global best value is -8.834928404850636
# Iteration 28: Global best value is -8.834928404850636
# Iteration 29: Global best value is -8.834928404850636
# Iteration 30: Global best value is -8.834928404850636
# Iteration 31: Global best value is -8.834928404850636
# Iteration 32: Global best value is -8.834928404850636
# Iteration 33: Global best value is -8.834928404850636
# Iteration 34: Global best value is -8.834928404850636
# Iteration 35: Global best value is -8.834928404850636
# Iteration 36: Global best value is -8.834928404850636
# Iteration 37: Global best value is -8.834928404850636
# Iteration 38: Global best value is -8.834928404850636
# Iteration 39: Global best value is -8.834928404850636
# Iteration 40: Global best value is -8.834928404850636
# Iteration 41: Global best value is -8.834928404850636
# Iteration 42: Global best value is -8.834928404850636
# Iteration 43: Global best value is -8.834928404850636
# Iteration 44: Global best value is -8.834928404850636
# Iteration 45: Global best value is -8.834928404850636
# Iteration 46: Global best value is -8.834928404850636
# Iteration 47: Global best value is -8.834928404850636
# Iteration 48: Global best value is -8.834928404850636
# Iteration 49: Global best value is -8.834928404850636
# Iteration 50: Global best value is -8.834928404850636
# Iteration 51: Global best value is -8.834928404850636
# Iteration 52: Global best value is -8.834928404850636
# Iteration 53: Global best value is -8.834928404850636
# Iteration 54: Global best value is -8.834928404850636
# Iteration 55: Global best value is -8.834928404850636
# Iteration 56: Global best value is -8.834928404850636
# Iteration 57: Global best value is -8.834928404850636
# Iteration 58: Global best value is -8.834928404850636
# Iteration 59: Global best value is -8.834928404850636
# Iteration 60: Global best value is -8.834928404850636
# Iteration 61: Global best value is -8.834928404850636
# Iteration 62: Global best value is -8.834928404850636
# Iteration 63: Global best value is -8.834928404850636
# Iteration 64: Global best value is -8.834928404850636
# Iteration 65: Global best value is -8.834928404850636
# Iteration 66: Global best value is -8.834928404850636
# Iteration 67: Global best value is -8.834928404850636
# Iteration 68: Global best value is -8.834928404850636
# Iteration 69: Global best value is -8.834928404850636
# Iteration 70: Global best value is -8.834928404850636
# Iteration 71: Global best value is -8.834928404850636
# Iteration 72: Global best value is -8.834928404850636
# Iteration 73: Global best value is -8.834928404850636
# Iteration 74: Global best value is -8.834928404850636
# Iteration 75: Global best value is -8.834928404850636
# Iteration 76: Global best value is -8.834928404850636
# Iteration 77: Global best value is -8.834928404850636
# Iteration 78: Global best value is -8.834928404850636
# Iteration 79: Global best value is -8.834928404850636
# Iteration 80: Global best value is -8.834928404850636
# Iteration 81: Global best value is -8.834928404850636
# Iteration 82: Global best value is -8.834928404850636
# Iteration 83: Global best value is -8.834928404850636
# Iteration 84: Global best value is -8.834928404850636
# Iteration 85: Global best value is -8.834928404850636
# Iteration 86: Global best value is -8.834928404850636
# Iteration 87: Global best value is -8.834928404850636
# Iteration 88: Global best value is -8.834928404850636
# Iteration 89: Global best value is -8.834928404850636
# Iteration 90: Global best value is -8.834928404850636
# Iteration 91: Global best value is -8.834928404850636
# Iteration 92: Global best value is -8.834928404850636
# Iteration 93: Global best value is -8.834928404850636
# Iteration 94: Global best value is -8.834928404850636
# Iteration 95: Global best value is -8.834928404850636
# Iteration 96: Global best value is -8.834928404850636
# Iteration 97: Global best value is -8.834928404850636
# Iteration 98: Global best value is -8.834928404850636
# Iteration 99: Global best value is -8.834928404850636
# Iteration 100: Global best value is -8.834928404850636
# The final global best position is [-8.8349284] with a value of -8.834928404850636
